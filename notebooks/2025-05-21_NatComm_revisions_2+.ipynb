# %% [markdown]
# # 2025-05-21
#
# - Remaking the A-O diagrams for the rocksalt with the green background overlap for stable phase
# - making corresponding diagrams for the 3+ and 4+ systems saeed and I identified
# - making new heatmaps

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.dpi"] = 400
plt.rcParams["figure.figsize"] = (1, 4)
plt.rcParams["font.size"] = 10
plt.rcParams["font.serif"] = "Helvetica"
plt.rcParams["axes.linewidth"] = 1.65
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["xtick.major.width"] = 1.65
plt.rcParams["ytick.major.width"] = 1.65
plt.rcParams["font.weight"] = "bold"

# %%
Mg_O = [
    [-50, -6.1068, 0      , 0], # x
    [0,   0,       -6.1068, -50], # y
    ]

plt.fill_between(
    [Mg_O[0][1] - 1, Mg_O[0][-1] + 1],
    y1=Mg_O[1][1],
    y2=Mg_O[1][2],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)

plt.plot(Mg_O[0], Mg_O[1], marker="s", linewidth=2, color="k")
#plt.plot(Mg_O[0][1:3], Mg_O[1][1:3], marker="s", linewidth=1.5, color="tab:green")

plt.xticks([-4, 0])

plt.xlim(Mg_O[0][1]-1, Mg_O[0][-1]+1)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Mg$^{\rm \bf 2\!+}$", weight="bold")

plt.show()

# %%
Co_O = [
    [-50, -3.2424,  -2.6727, -2.2739, -1.1674, 0,       0], # x
    [0,   0,        -0.2848, -0.5715, -1.4014, -2.5688, -50], # y
    ]

plt.plot(Co_O[0], Co_O[1], marker="s", linewidth=2, color="k")
#plt.plot(Co_O[0][4:6], Co_O[1][4:6], marker="s", linewidth=1.5, color="tab:green")

plt.fill_between(
    [Co_O[0][1] - 1, Co_O[0][-1] + 1],
    y1=Co_O[1][4],
    y2=Co_O[1][5],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)

plt.xticks([-3, 0])

plt.xlim(Co_O[0][1]-1, Co_O[0][-1]+1)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Co$^{\rm \bf 2\!+}$", weight="bold")

plt.show()

# %%
Ni_O = [
    [-50, -2.4424,  -2.4174,    0,         0], # x
    [0,   0,        -0.0187,    -2.4362,   -50], # y
    ]

plt.plot(Ni_O[0], Ni_O[1], marker="s", linewidth=2, color="k")
#plt.plot(Ni_O[0][2:4], Ni_O[1][2:4], marker="s", linewidth=1.5, color="tab:green")

plt.fill_between(
    [Ni_O[0][1] - 1, Ni_O[0][-1] + 1],
    y1=Ni_O[1][2],
    y2=Ni_O[1][3],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)

plt.xticks([-2, 0])

plt.xlim(Ni_O[0][1]-1, Ni_O[0][-1]+1)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Ni$^{\rm \bf 2\!+}$", weight="bold")

plt.show()

# %%
Cu_O = [
    [-50, -2.0828,  -1.4911,    -0.0479,    0,          0], # x
    [0,   0,        -0.3945,    -1.8377,    -1.9335,    -50], # y
    ]

plt.plot(Cu_O[0], Cu_O[1], marker="s", linewidth=2, color="k")
#plt.plot(Cu_O[0][2:4], Cu_O[1][2:4], marker="s", linewidth=1.5, color="tab:green")

plt.fill_between(
    [Cu_O[0][1] - 1, Cu_O[0][-1] + 1],
    y1=Cu_O[1][2],
    y2=Cu_O[1][3],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)

plt.xticks([-2, 0])

plt.xlim(Cu_O[0][1]-1, Cu_O[0][-1]+1)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Cu$^{\rm \bf 2\!+}$", weight="bold")

plt.show()

# %%
Zn_O = [
    [-50,   -3.5818,    0,    0], # x
    [0,     0,          -3.5818, -50], # y
    ]

plt.plot(Zn_O[0], Zn_O[1], marker="s", linewidth=2, color="k")
#plt.plot(Zn_O[0][1:3], Zn_O[1][1:3], marker="s", linewidth=1.5, color="tab:green")

plt.fill_between(
    [Zn_O[0][1] - 1, Zn_O[0][-1] + 1],
    y1=Zn_O[1][1],
    y2=Zn_O[1][2],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)

plt.xticks([-3, 0])

plt.xlim(Zn_O[0][1]-1, Zn_O[0][-1]+1)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Zn$^{\rm \bf 2\!+}$", weight="bold")

plt.show()

# %%
Mn_O = [
    [-50, -5.4175, -3.8867, -2.7802, -1.4807, 0,       0], # x
    [0,   0,       -0.7654, -1.5031, -2.4777, -3.9584, -50], # y
    ]

plt.plot(Mn_O[0], Mn_O[1], marker="s", linewidth=2, color="k")
#plt.plot(Mn_O[0][4:6], Mn_O[1][4:6], marker="s", linewidth=1.5, color="tab:green")

plt.fill_between(
    [Mn_O[0][1] - 1, Mn_O[0][-1] + 1],
    y1=Mn_O[1][4],
    y2=Mn_O[1][5],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)

plt.xticks([-4, 0])

plt.xlim(Mn_O[0][1]-1, Mn_O[0][-1]+1)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Mn$^{\rm \bf 2\!+}$", weight="bold")

plt.show()

# %%
Fe_O = [
    [-50,   -4.2677,  -0.3537,    0,          0], # x
    [0,     0,        -2.6094,    -2.9630,     -50], # y
    ]

plt.plot(Fe_O[0], Fe_O[1], marker="s", linewidth=2, color="k")
#plt.plot(Fe_O[0][2:4], Fe_O[1][2:4], marker="s", linewidth=1.5, color="tab:green")

plt.fill_between(
    [Fe_O[0][1] - 1, Fe_O[0][-1] + 1],
    y1=Fe_O[1][2],
    y2=Fe_O[1][3],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)

plt.xticks([-4, 0])

plt.xlim(Fe_O[0][1]-1, Fe_O[0][-1]+1)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Fe$^{\rm \bf 2\!+}$", weight="bold")

plt.show()

# %%
Sc_O = [
    [-50, -9.9218, 0,          0], # x
    [0,   0,       -6.6146,    -50], # y
    ]

plt.plot(Sc_O[0], Sc_O[1], marker="s", linewidth=2  , color="k")
#plt.plot(Fe_O[0][2:4], Fe_O[1][2:4], marker="s", linewidth=1.5, color="tab:green")

"""plt.fill_between(
    [Sc_O[0][1] - 1, Sc_O[0][-1] + 1],
    y1=Sc_O[1][2],
    y2=Fe_O[1][3],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)"""

plt.xticks([-6, 0])

plt.xlim(Sc_O[0][1]-2, Sc_O[0][-1]+2)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Sc$^{\rm \bf 2\!+}$", weight="bold")

plt.show()

# %%
cation = "Ti"

A_O = [
    [-50, -10.5049, -1.5545,    -1.4674,    -0.9305,    -0.2908,    -0.173,     -0.0457,    -0.0457,    0,          0], # x
    [0,   0,        -4.4752,    -4.5275,    -4.8854,    -5.5251,    -5.7607,    -6.1424,    -6.1424,    -6.4169,    -50], # y
    ]

plt.plot(A_O[0], A_O[1], marker="s", linewidth=2, color="k")
#plt.plot(A_O[0][4:6], A_O[1][4:6], marker="s", linewidth=2, color="tab:green")

plt.fill_between(
    [A_O[0][1] - 2, A_O[0][-1] + 2],
    y1=A_O[1][4],
    y2=A_O[1][5],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)

plt.xticks([-8, 0])

plt.xlim(A_O[0][1]-2, A_O[0][-1]+2)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Ti$^{\rm \bf 2\!+}$", weight="bold")

plt.show()

# %%
cation = "V"

A_O = [
    [-50, -8.0116,  -5.1578,  -3.1534,  -2.8274,    0,          0], # x
    [0,   0,        -1.1415,  -2.1437,  -2.3393,    -4.2242,    -50], # y
    ]

plt.plot(A_O[0], A_O[1], marker="s", linewidth=2, color="k")
#plt.plot(A_O[0][4:6], A_O[1][4:6], marker="s", linewidth=2, color="tab:green")

"""plt.fill_between(
    [A_O[0][1] - 2, A_O[0][-1] + 2],
    y1=A_O[1][4],
    y2=A_O[1][5],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)"""

plt.xticks([-6, 0])

plt.xlim(A_O[0][1]-2, A_O[0][-1]+2)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"V$^{\rm \bf 2\!+}$", weight="bold")

plt.show()

# %%
cation = "Cr"

A_O = [
    [-50,   -6.2295,    -5.7111,    -5.2366,  0,        0], # x
    [0,     0,          -0.2160,    -0.4533,  -3.9443,  -50], # y
    ]

plt.plot(A_O[0], A_O[1], marker="s", linewidth=2, color="k")
#plt.plot(A_O[0][1:3], A_O[1][1:3], marker="s", linewidth=2, color="tab:green")

plt.xticks([-4, 0])

plt.xlim(A_O[0][1]-2, A_O[0][-1]+2)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Cr$^{\rm \bf 2\!+}$", weight="bold")

plt.show()
