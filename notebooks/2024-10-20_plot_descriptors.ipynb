# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 250
plt.rcParams["figure.figsize"] = (6, 4)

# %%
data = pd.read_csv("../data/descriptors-5cation-ALL-noCa.csv")
data_sorted = data.sort_values(by=["chempot overlap (eV)"], ascending=False)
data_sorted
# Out:
#    composition  total energy (eV/atom)  formation energy (eV/atom)  \
# 0   MgCoNiCuZn               -5.992476                   -1.533727
# 1   MgMnCoNiZn               -6.719349                   -1.754320
# 2   MgMnFeCoZn               -7.043499                   -1.809481
# 3   MgMnFeCoNi               -7.382521                   -1.696463
# 4   MgMnFeNiZn               -6.909994                   -1.808794
# 5   MgFeCoNiZn               -6.545707                   -1.649876
# 6   MnFeCoNiZn               -7.091146                   -1.439142
# 9   MgMnNiCuZn               -6.363947                   -1.699828
# 10  MnCoNiCuZn               -6.551397                   -1.336475
# 8   MgMnCoCuZn               -6.499017                   -1.702081
# 7   MgMnCoNiCu               -6.844773                   -1.595797
# 11  MgMnFeCoCu               -7.173484                   -1.655519
# 12  MgMnFeNiCu               -7.038704                   -1.653558
# ...

# %%
plt.bar(data_sorted["composition"], data_sorted["chempot overlap (eV)"], color="tab:grey")
plt.ylim(-0.85, 0.5)
plt.xticks(rotation=90)
#plt.title("Cation Cohort = Mg, Mn, Fe, Co, Ni, Cu, Zn")
plt.ylabel("O$_{2}$ Chemical Potential Overlap (eV)")
plt.axhline(0, color='black', linestyle='--', zorder=0)
