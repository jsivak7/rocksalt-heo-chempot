# %% [markdown]
# # 2025-05-21
#
# - Remaking the A-O diagrams for the rocksalt with the green background overlap for stable phase
# - making corresponding diagrams for the 3+ and 4+ systems saeed and I identified
# - making new heatmaps

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.dpi"] = 400
plt.rcParams["figure.figsize"] = (1, 4)
plt.rcParams["font.size"] = 10
plt.rcParams["font.serif"] = "Helvetica"
plt.rcParams["axes.linewidth"] = 1.65
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["xtick.major.width"] = 1.65
plt.rcParams["ytick.major.width"] = 1.65
plt.rcParams["font.weight"] = "bold"

# %%
Ce_O = [
    [-50, -11.785389,   -4.329403,  -2.588021,  -0.934633,  -0.555993,  0.000000, 0], # x
    [0,   0,            -3.727993,  -4.695427,  -5.659904,  -5.912330,  -6.468324, -50], # y
    ]

plt.fill_between(
    [Ce_O[0][1] - 2, Ce_O[0][-1] + 2],
    y1=Ce_O[1][4],
    y2=Ce_O[1][5],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)

plt.plot(Ce_O[0], Ce_O[1], marker="s", linewidth=2, color="k")

plt.xticks([-8, 0])

plt.xlim(Ce_O[0][1]-2, Ce_O[0][-1]+2)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Ce$^{\rm \bf 3.0\!+}$", weight="bold")

plt.show()

# %%
Y_O = [
    [-50, -9.9273,  0.0000, 0], # x
    [0,   0.0000,   -6.6182, -50], # y
    ]

plt.fill_between(
    [Y_O[0][1] - 2, Y_O[0][-1] + 2],
    y1=Y_O[1][1],
    y2=Y_O[1][2],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)

plt.plot(Y_O[0], Y_O[1], marker="s", linewidth=2, color="k")

plt.xticks([-6, 0])

plt.xlim(Y_O[0][1]-2, Y_O[0][-1]+2)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Y$^{\rm \bf 3\!+}$", weight="bold")

plt.show()

# %%
La_O = [
    [-50, -9.685358,  0.0000, 0], # x
    [0,   0.0000,   -6.456905, -50], # y
    ]

plt.fill_between(
    [La_O[0][1] - 2, La_O[0][-1] + 2],
    y1=La_O[1][1],
    y2=La_O[1][2],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)

plt.plot(La_O[0], La_O[1], marker="s", linewidth=2, color="k")

plt.xticks([-8, 0])

plt.xlim(La_O[0][1]-2, La_O[0][-1]+2)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"La$^{\rm \bf 3\!+}$", weight="bold")

plt.show()

# %%
Pr_O = [
    [-50, -9.337742,  0.0000, 0], # x
    [0,   0.0000,   -6.225161, -50], # y
    ]

plt.fill_between(
    [Pr_O[0][1] - 2, Pr_O[0][-1] + 2],
    y1=Pr_O[1][1],
    y2=Pr_O[1][2],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)

plt.plot(Pr_O[0], Pr_O[1], marker="s", linewidth=2, color="k")

plt.xticks([-6, 0])

plt.xlim(Pr_O[0][1]-2, Pr_O[0][-1]+2)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Pr$^{\rm \bf 3\!+}$", weight="bold")

plt.show()

# %%
Sm_O = [
    [-50, -9.654881,  0.0000, 0], # x
    [0,   0.0000,   -6.436587, -50], # y
    ]

plt.fill_between(
    [Sm_O[0][1] - 2, Sm_O[0][-1] + 2],
    y1=Sm_O[1][1],
    y2=Sm_O[1][2],
    color="tab:green",
    alpha=0.2,
    zorder=1,
    linewidth=0,
)

plt.plot(Sm_O[0], Sm_O[1], marker="s", linewidth=2, color="k")

plt.xticks([-8, 0])

plt.xlim(Sm_O[0][1]-2, Sm_O[0][-1]+2)
plt.ylim(-7.75, 0.75)

plt.xlabel(r"μ$_{\rm \bf A}$ - μ$_{\rm \bf A}^{\rm \bf o}$ (eV)", weight="bold")
plt.ylabel(r"μ$_{\rm \bf O}$ - μ$_{\rm \bf O}^{\rm \bf o}$ (eV)", weight="bold")

plt.title(r"Sm$^{\rm \bf 3\!+}$", weight="bold")

plt.show()

# %% [markdown]
# # overlap

# %% [markdown]
# overlap_matrix = [
#     []
# ]
